# %%
import numpy as np

# %%
import pandas as pd

# %%
employment_data_raw = pd.read_csv('/Users/biswajeetparija/Downloads/machine-readable-business-employment-data-sep-2023-quarter.csv')

# %%
employment_data_raw.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2      BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3      BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4      BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# ...

# %%
employment_data_raw.sort_index
# Out:
# <bound method DataFrame.sort_index of       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 22184    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 22185    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 22186    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 22187    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 22188    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# ...

# %%
employment_data_raw
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 22184    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 22185    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 22186    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 22187    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 22188    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
pd.isna(employment_data_raw[0:15])
# Out:
#     Series_reference  Period  Data_value  Suppressed  STATUS  UNITS  \
# 0              False   False       False        True   False  False
# 1              False   False       False        True   False  False
# 2              False   False       False        True   False  False
# 3              False   False       False        True   False  False
# 4              False   False       False        True   False  False
# 5              False   False       False        True   False  False
# 6              False   False       False        True   False  False
# 7              False   False       False        True   False  False
# 8              False   False       False        True   False  False
# 9              False   False       False        True   False  False
# 10             False   False       False        True   False  False
# 11             False   False       False        True   False  False
# 12             False   False       False        True   False  False
# ...

# %%
employment_data_raw.columns
# Out:
# Index(['Series_reference', 'Period', 'Data_value', 'Suppressed', 'STATUS',
#        'UNITS', 'Magnitude', 'Subject', 'Group', 'Series_title_1',
#        'Series_title_2', 'Series_title_3', 'Series_title_4', 'Series_title_5'],
#       dtype='object')

# %%
employment_data_raw.loc[0:15, "Suppressed"].isna
# Out:
# <bound method Series.isna of 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# Name: Suppressed, dtype: object>

# %%
employment_data_test = employment_data_raw.copy()

# %%
employment_data_test.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2      BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3      BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4      BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# ...

# %%
employment_data_test.describe
# Out:
# <bound method NDFrame.describe of       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 22184    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 22185    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 22186    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 22187    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 22188    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# ...
